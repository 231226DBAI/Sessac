# %%
#!pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from glob import glob
import pandas as pd

path = (r"C:\Users\bluecom013\Desktop\class\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\9장\*.*")
#path=path.replace("\\","\\\\")
file_list=glob(path)

file_list
# Out:
# ['C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_건강.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_경제.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_관계및사회참여.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_교육.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_삶의만족도.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_안전.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_여가.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_환경.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\예제09.ipynb']

# %%
교육 = pd.read_excel(file_list[3])[['시도','구군','평균']]
교육 = pd.read_excel(file_list[3]).iloc[:,1:4]

건강 = pd.read_excel(file_list[0]).iloc[:,1:4]
건강 = pd.read_excel(file_list[1]).iloc[:,1:4]
관계 = pd.read_excel(file_list[2]).iloc[:,1:4]
삶의 = pd.read_excel(file_list[4]).iloc[:,1:4]
안전 = pd.read_excel(file_list[5]).iloc[:,1:4]
여가= pd.read_excel(file_list[6]).iloc[:,1:4]

# %%
건강[(건강['시도']=='서울특별시') &(건강['구군']=='중구')]
건강[(건강['시도']=='서울특별시') &(건강['평균']>=0.5)]
건강[(건강['평균']>0.8) | (건강['평균']<0.3)]['시도']

#특별이 포함된 시도자료중에서 평균값이 0.8보다 크거나 또는 평균값이 0.3보다 작은 시도 필드만 보는게 나음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 건강[(건강['시도']=='서울특별시') &(건강['구군']=='중구')]
#       2 건강[(건강['시도']=='서울특별시') &(건강['평균']>=0.5)]
# ----> 3 건강[(건강['평균']>0.8) | (건강['평균']<0.3)]['시도'].str.contatins('특별')
#
# AttributeError: 'StringMethods' object has no attribute 'contatins'

# %%
tmp=건강[건강['시도'].str.contains('특별')]['평균']>0.3

(tmp['평균']>0.8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bluecom013\miniconda3\envs\openai\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '평균'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 3
#       1 tmp=건강[건강['시도'].str.contains('특별')]['평균']>0.3
# ----> 3 (tmp['평균']>0.8)
#
# ...

# %%
###############################
####건강 자료에서 시도별 자료를 저장
############건강 자료에서 건강_서울특별시.csv 로 저장
###건강_부산광역시.csv 로 저장
###건강_경기.csv 로 저장
################################

조건리스트 = 건강['시도'].unique()
for 조건 in 조건리스트:
    tmp = 건강[건강['시도']==조건]
    tmp.to_csv("C:/Users/bluecom013/Desktop/class/데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제/9장/" + 조건 +'.csv', index = False, encoding = 'utf-8')
    print(조건)
# Out:
# 서울특별시
# 부산광역시
# 대구광역시
# 인천광역시
# 광주광역시
# 대전광역시
# 울산광역시
# 세종특별자치시
# 경기도
# 강원도
# 충청북도
# 충청남도
# 전라북도
# 전라남도
# 경상북도
# 경상남도
# 제주특별자치도

# %%
건강['시군구'] = 건강['시도']+'_'+건강['구군']
건강.head()
'''
for x in 건강['평균']:
    if x > 0.5:
        result.append('상')
    else:
        result.append('하')
'''
#return 하면서 바로 자료 추가 하려면 람다 실행
건강['비고'] = 건강['평균'].apply(lambda x: '상' if x > 0.5 else '하')

# %%
df=건강.iloc[:,:-2].copy() # 깊은복사를 해야, 건강데이터가 변경되었을 때 df 데이터가 영향 받지 않음, df=건강 영향 받음

df['비고'] = 0

def aaa (row):
    if row>0.5:
        return '상'
    else:
        return '하'
    
for cnt,x in enumerate(df['평균']):
    df['비고'][cnt]=aaa(x)
# Out:
#           시도    구군      평균
# 0      서울특별시   종로구  1.0000
# 1      서울특별시    중구  0.9806
# 2      서울특별시   용산구  0.6915
# 3      서울특별시   성동구  0.6533
# 4      서울특별시   광진구  0.4445
# ..       ...   ...     ...
# 224     경상남도   함양군  0.1401
# 225     경상남도   거창군  0.1799
# 226     경상남도   합천군  0.0373
# 227  제주특별자치도   제주시  0.4250
# 228  제주특별자치도  서귀포시  0.4250
#
# [229 rows x 3 columns]

# %%
def create_variables(file_paths, variable_names):
    """
    파일 경로 리스트와 변수명 리스트를 받아서 변수명을 생성하고 해당 변수에 파일 경로를 할당하는 함수.

    Parameters:
    - file_paths (list): 파일 경로들을 담은 리스트.
    - variable_names (list): 생성할 변수명들을 담은 리스트.

    Returns:
    - variables (dict): 생성된 변수명과 파일 경로를 담은 딕셔너리.
    """
    variables = {}

    for file_path, variable_name in zip(file_paths, variable_names):
        # 변수명을 'happy_' + 주어진 변수명으로 설정
        variable_name = 'happy_' + variable_name

        # 파일 경로를 변수에 할당서울특
        variables[variable_name] = file_path

    return variables

# %%
file_list[:-1]
# Out:
# ['C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_건강.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_경제.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_관계및사회참여.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_교육.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_삶의만족도.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_안전.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_여가.xlsx',
#  'C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\대한민국행복지도_환경.xlsx']

# %%
def create_variables(file_paths, variable_names):
    """
    파일 경로 리스트와 변수명 리스트를 받아서 변수명을 생성하고 해당 변수에 파일 경로를 할당하는 함수.

    Parameters:
    - file_paths (list): 파일 경로들을 담은 리스트.
    - variable_names (list): 생성할 변수명들을 담은 리스트.

    Returns:
    - variables (dict): 생성된 변수명과 파일 경로를 담은 딕셔너리.
    """
    variables = {}

    for file_path, variable_name in zip(file_paths, variable_names):
        # 변수명을 'happy_' + 주어진 변수명으로 설정
        variable_name = 'happy_' + variable_name

        # 파일 경로를 변수에 할당
        variables[variable_name] = file_path

    return variables




variable_names = ['health', 'econo', 'relation', 'edu', 'life', 'safe', 'leisure', 'environ']



result_variables = create_variables(file_list[:-1], variable_names)

for variable_name, content in result_variables.items():
    print(f"{variable_name}: {content}")

# %%
from glob import glob

import pandas as pd

path = r"C:\Users\bluecom013\Desktop\class\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\9장\*.xlsx"
path = path.replace("\\","\\\\") 
print("path=====",path)

fileList=glob(path)

file=fileList[0]

df=pd.read_excel(file).iloc[:,1:4]

happy=pd.DataFrame({'시도': df['시도'].unique()})

#print(happy[:3])  #시도데이터를 그룹으로 제작

 

 

 

for file in fileList:

    print(file)

    colName=file.split('_')[-1].split('.')[0]

    df=pd.read_excel(file).iloc[:,1:4]

    df.columns=['시도','군구','평균']

    tmp=df['평균'].groupby(df['시도']).mean()

    happy=pd.merge(happy,tmp.rename(colName), on='시도')

 

happy
# Out:
# path===== C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\\*.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_건강.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_경제.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_관계및사회참여.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_교육.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_삶의만족도.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_안전.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_여가.xlsx
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\9장\대한민국행복지도_환경.xlsx
# ...
