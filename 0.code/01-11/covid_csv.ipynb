# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


path = glob(r"C:\Users\bluecom013\Desktop\class\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\6장\iris.csv")
path = path[0].replace("\\","\\\\")
print(path)

df = pd.read_csv(path)
df.head()
# Out:
# C:\\Users\\bluecom013\\Desktop\\class\\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\\6장\\iris.csv
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.hist(df.SepalLength, bins=50)
# Out:
# (array([ 1.,  3.,  1.,  0.,  4.,  2.,  5.,  0.,  6., 10.,  0.,  9.,  4.,
#          1.,  0.,  6.,  7.,  0.,  6.,  8.,  7.,  0.,  3.,  6.,  0.,  6.,
#          4.,  9.,  0.,  7.,  5.,  2.,  0.,  8.,  3.,  0.,  4.,  1.,  1.,
#          0.,  3.,  1.,  0.,  1.,  0.,  1.,  0.,  4.,  0.,  1.]),
#  array([4.3  , 4.372, 4.444, 4.516, 4.588, 4.66 , 4.732, 4.804, 4.876,
#         4.948, 5.02 , 5.092, 5.164, 5.236, 5.308, 5.38 , 5.452, 5.524,
#         5.596, 5.668, 5.74 , 5.812, 5.884, 5.956, 6.028, 6.1  , 6.172,
#         6.244, 6.316, 6.388, 6.46 , 6.532, 6.604, 6.676, 6.748, 6.82 ,
#         6.892, 6.964, 7.036, 7.108, 7.18 , 7.252, 7.324, 7.396, 7.468,
#         7.54 , 7.612, 7.684, 7.756, 7.828, 7.9  ]),
#  <BarContainer object of 50 artists>)

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species'], dtype='object')

# %%
df.PetalWidth.value_counts(sort=False)
df.SepalWidth.value_counts(sort=True)
# Out:
# SepalWidth
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %%
df.isna().mean().sort_values(ascending=False).plot( kind='bar', figsize=(10,3),  grid=True, color='blue', edgecolor='black', linewidth=2, rot=42)
plt.title('NaN')
plt.xlabel('Name of column')
plt.ylabel('Frac of Nan')
plt.show()

# %%
sns.pairplot(df,height=3.3, aspect=1.3)
