# %%
#!pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.15.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in c:\users\bluecom013\miniconda3\envs\openai\lib\site-packages (from folium) (1.26.2)
# Collecting requests (from folium)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Downloading MarkupSafe-2.1.3-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->folium)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium)
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->folium)
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ---------------------------------------- 97.0/97.0 kB ? eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.2 kB ? eta -:--:--
#    ---------------------------------------- 133.2/133.2 kB 4.0 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#    ---------------------------------------- 56.3/56.3 kB ? eta 0:00:00
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.5 kB ? eta -:--:--
#    --------------------------------------- 162.5/162.5 kB 10.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 5.6 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB ? eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp312-cp312-win_amd64.whl (16 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#    ---------------------------------------- 104.6/104.6 kB ? eta 0:00:00
# Installing collected packages: xyzservices, urllib3, MarkupSafe, idna, charset-normalizer, certifi, requests, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.3 branca-0.7.0 certifi-2023.11.17 charset-normalizer-3.3.2 folium-0.15.1 idna-3.6 jinja2-3.1.3 requests-2.31.0 urllib3-2.1.0 xyzservices-2023.10.1

# %%
import folium
# location에 위도, 경도 정보를 입력하여 입력한 위,경도 좌표를 기준으로 지도를 그릴 수 있습니다.

# 이때 zoom_start 정보를 지정하여 확대의 정도를 지정할 수 있습니다.

# 참고: zoom_start의 범위는 최대 18 입니다.


# 위도
latitude = 37.394946
# 경도
longitude = 127.111104

m = folium.Map(location=[latitude, longitude],
               zoom_start=15, 
               width=750, 
               height=500
              )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833ce8be53d35acdfd18242e01dac2a5 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833ce8be53d35acdfd18242e01dac2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833ce8be53d35acdfd18242e01dac2a5 = L.map(
#                 &quot;map_833ce8be53d35acdfd18242e01dac2a5&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85c320e0658dea346d2144f587c64b97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([latitude, longitude],
              popup="판교역",
              tooltip="판교역 입구").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833ce8be53d35acdfd18242e01dac2a5 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833ce8be53d35acdfd18242e01dac2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833ce8be53d35acdfd18242e01dac2a5 = L.map(
#                 &quot;map_833ce8be53d35acdfd18242e01dac2a5&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85c320e0658dea346d2144f587c64b97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_74f7ce4411912e50e723896996d7155d = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#         var popup_3aea99e1934b27e7873b3ba81beb3962 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b95202c77ff38c43d6183e44803a9c3 = $(`&lt;div id=&quot;html_0b95202c77ff38c43d6183e44803a9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_3aea99e1934b27e7873b3ba81beb3962.setContent(html_0b95202c77ff38c43d6183e44803a9c3);
#
#
#
#         marker_74f7ce4411912e50e723896996d7155d.bindPopup(popup_3aea99e1934b27e7873b3ba81beb3962)
#         ;
#
#
#
#
#             marker_74f7ce4411912e50e723896996d7155d.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([latitude, longitude],
              popup="판교역",
              tooltip="판교역 입구", 
              icon=folium.Icon('red', icon='star'),
             ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833ce8be53d35acdfd18242e01dac2a5 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833ce8be53d35acdfd18242e01dac2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833ce8be53d35acdfd18242e01dac2a5 = L.map(
#                 &quot;map_833ce8be53d35acdfd18242e01dac2a5&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85c320e0658dea346d2144f587c64b97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_74f7ce4411912e50e723896996d7155d = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#         var popup_3aea99e1934b27e7873b3ba81beb3962 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b95202c77ff38c43d6183e44803a9c3 = $(`&lt;div id=&quot;html_0b95202c77ff38c43d6183e44803a9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_3aea99e1934b27e7873b3ba81beb3962.setContent(html_0b95202c77ff38c43d6183e44803a9c3);
#
#
#
#         marker_74f7ce4411912e50e723896996d7155d.bindPopup(popup_3aea99e1934b27e7873b3ba81beb3962)
#         ;
#
#
#
#
#             marker_74f7ce4411912e50e723896996d7155d.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_49c9fe1228186046f00c4b6cf709a1c2 = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var icon_ed912b1e6448b1b7dc44aae66097ec0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49c9fe1228186046f00c4b6cf709a1c2.setIcon(icon_ed912b1e6448b1b7dc44aae66097ec0d);
#
#
#         var popup_d4da550eace60f0d1a125368c5e96be7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c46eb1d68ede4290725a1f6a3467e46 = $(`&lt;div id=&quot;html_8c46eb1d68ede4290725a1f6a3467e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_d4da550eace60f0d1a125368c5e96be7.setContent(html_8c46eb1d68ede4290725a1f6a3467e46);
#
#
#
#         marker_49c9fe1228186046f00c4b6cf709a1c2.bindPopup(popup_d4da550eace60f0d1a125368c5e96be7)
#         ;
#
#
#
#
#             marker_49c9fe1228186046f00c4b6cf709a1c2.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([latitude, longitude],
              popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/dpwTOQri42s" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>',
              tooltip="판교역 입구").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833ce8be53d35acdfd18242e01dac2a5 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833ce8be53d35acdfd18242e01dac2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833ce8be53d35acdfd18242e01dac2a5 = L.map(
#                 &quot;map_833ce8be53d35acdfd18242e01dac2a5&quot;,
#                 {
#                     center: [37.394946, 127.111104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85c320e0658dea346d2144f587c64b97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_74f7ce4411912e50e723896996d7155d = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#         var popup_3aea99e1934b27e7873b3ba81beb3962 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b95202c77ff38c43d6183e44803a9c3 = $(`&lt;div id=&quot;html_0b95202c77ff38c43d6183e44803a9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_3aea99e1934b27e7873b3ba81beb3962.setContent(html_0b95202c77ff38c43d6183e44803a9c3);
#
#
#
#         marker_74f7ce4411912e50e723896996d7155d.bindPopup(popup_3aea99e1934b27e7873b3ba81beb3962)
#         ;
#
#
#
#
#             marker_74f7ce4411912e50e723896996d7155d.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_49c9fe1228186046f00c4b6cf709a1c2 = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var icon_ed912b1e6448b1b7dc44aae66097ec0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49c9fe1228186046f00c4b6cf709a1c2.setIcon(icon_ed912b1e6448b1b7dc44aae66097ec0d);
#
#
#         var popup_d4da550eace60f0d1a125368c5e96be7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c46eb1d68ede4290725a1f6a3467e46 = $(`&lt;div id=&quot;html_8c46eb1d68ede4290725a1f6a3467e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;판교역&lt;/div&gt;`)[0];
#                 popup_d4da550eace60f0d1a125368c5e96be7.setContent(html_8c46eb1d68ede4290725a1f6a3467e46);
#
#
#
#         marker_49c9fe1228186046f00c4b6cf709a1c2.bindPopup(popup_d4da550eace60f0d1a125368c5e96be7)
#         ;
#
#
#
#
#             marker_49c9fe1228186046f00c4b6cf709a1c2.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_85c320e0658dea346d2144f587c64b97.addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#             var marker_ff037c945a82b9ee52d2fe6722835d07 = L.marker(
#                 [37.394946, 127.111104],
#                 {}
#             ).addTo(map_833ce8be53d35acdfd18242e01dac2a5);
#
#
#         var popup_a173b8d40d8debcc2de29d8f1735b53d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7d088520b803e69476fae81e35f1cc0 = $(`&lt;div id=&quot;html_e7d088520b803e69476fae81e35f1cc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe width=&quot;560&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/dpwTOQri42s&quot; title=&quot;YouTube video player&quot; frameborder=&quot;0&quot; allow=&quot;accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture&quot; allowfullscreen&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_a173b8d40d8debcc2de29d8f1735b53d.setContent(html_e7d088520b803e69476fae81e35f1cc0);
#
#
#
#         marker_ff037c945a82b9ee52d2fe6722835d07.bindPopup(popup_a173b8d40d8debcc2de29d8f1735b53d)
#         ;
#
#
#
#
#             marker_ff037c945a82b9ee52d2fe6722835d07.bindTooltip(
#                 `&lt;div&gt;
#                      판교역 입구
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marke

# %%
from glob import glob
import pandas as pd

path = (r"C:\Users\bluecom013\Desktop\class\데이터_분석을_위한_전처리와_시각화_with_파이썬_예제_및_연습_문제\9장\*.*")
#path=path.replace("\\","\\\\")
file_list=glob(path)
file_list
df = pd.read_csv(file_list[0])
df
# Out:
#     Unnamed: 0       시도    삶의 만족도        건강        안전        환경        경제  \
# 0            0    서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820
# 1            1    부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038
# 2            2    대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975
# 3            3    인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820
# 4            4    광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380
# 5            5    대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260
# 6            6    울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580
# 7            7  세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900
# 8            8      경기도  0.426023  0.353952  0.325255  0.557977  0.468926
# 9            9      강원도  0.619506  0.329506  0.548000  0.639839  0.386861
# 10          10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755
# 11          11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893
# 12          12     전라북도  0.608193  0.421300  0.410914  0.670586  0.196543
# 13          13     전라남도  0.547709  0.424732  0.565195  0.700573  0.202668
# 14          14     경상북도  0.502223  0.264114  0.484835  0.614265  0.303355
# 15          15     경상남도  0.530794  0.312722  0.475561  0.735600  0.325017
# 16          16  제주특별자치도  0.711300  0.253700  0.446100  0.684200  0.425000
#
#           교육   관계및사회참여        여가
# 0   0.399412  0.390656  0.286732
# 1   0.504594  0.294719  0.153587
# 2   0.585838  0.407486  0.234925
# 3   0.502920  0.504920  0.244590
# 4   0.689680  0.637800  0.454980
# 5   0.840780  0.510820  0.347960
# 6   0.763240  0.676440  0.418420
# 7   0.587000  0.673700  0.447800
# 8   0.668619  0.601532  0.377561
# 9   0.488533  0.563122  0.632750
# 10  0.592409  0.372782  0.702891
# 11  0.648047  0.448720  0.625347
# 12  0.446936  0.487464  0.667900
# 13  0.420019  0.481323  0.658668
# 14  0.428252  0.402183  0.490804
# 15  0.624022  0.395378  0.463750
# 16  0.646800  0.610700  0.694800

# %%
import json
a = r"https://github.com/vuski/admdongkor/blob/master/ver20230701/HangJeongDong_ver20230701.geojson"
# Out:
# https://github.com/vuski/admdongkor/blob/master/ver20230701/HangJeongDong_ver20230701.geojson
